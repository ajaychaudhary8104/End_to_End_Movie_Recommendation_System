# %%
import os

# %%
# %pwd
# Out:
# 'd:\\End_to_End_movie_Recommendation_system'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\'

# %%
d1 = {"key1": "value1", "key2": "value2"}

# %%
d1["key2"]
# Out:
# 'value2'

# %%
d1.key
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Hp\anaconda3\envs\movie-rec\Lib\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hp\AppData\Local\Temp\ipykernel_21684\3617365923.py", line 1, in <module>
#     d1.key
# AttributeError: 'dict' object has no attribute 'key'. Did you mean: 'keys'?
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Hp\anaconda3\envs\movie-rec\Lib\site-packages\IPython\core\interactiveshell.py", line 2201, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Hp\anaconda3\envs\movie-rec\Lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     return FormattedTB.structured_traceback(
# ...

# %%
from box.config_box import ConfigBox

config = ConfigBox({"key": "value", "nested": {"inner": "data"}})

# %%
type(config)
# Out:
# box.config_box.ConfigBox

# %%
config.key
# Out:
# 'value'

# %%
config.nested.inner
# Out:
# 'data'

# %%
# %pip install --upgrade python-box
# Out:
# ...
#   Using cached python_box-7.3.2-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Using cached python_box-7.3.2-cp312-cp312-win_amd64.whl (1.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_product(a : int, b : int) -> int:
    return a * b

# %%
get_product(4, 5)
# Out:
# 20

# %%
get_product(4, "5")
# Out:
# '5555'

# %%
# %pip install --upgrade ensure
# Out:
# ...
#   Using cached ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached ensure-1.0.4-py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(a : int, b : int) -> int:
    return a * b

# %%
get_product(4,5)
# Out:
# 20

# %%
get_product(5,"4")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Hp\anaconda3\envs\movie-rec\Lib\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hp\AppData\Local\Temp\ipykernel_21684\370444886.py", line 1, in <module>
#     get_product(5,"4")
#   File "c:\Users\Hp\anaconda3\envs\movie-rec\Lib\site-packages\ensure\main.py", line 870, in __call__
#     raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
# ensure.main.EnsureError: Argument b of type <class 'str'> to <function get_product at 0x000001E2C2792480> does not match annotation type <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Hp\anaconda3\envs\movie-rec\Lib\site-packages\IPython\core\interactiveshell.py", line 2201, in showtraceback
# ...
